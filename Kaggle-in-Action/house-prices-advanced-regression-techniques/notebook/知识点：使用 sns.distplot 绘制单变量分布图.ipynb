# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')

# %%
df_train.shape
# Out:
# (1460, 81)

# %% [markdown]
# ## 使用 sns.distplot 绘制单变量分布图

# %%
# 正偏
plt.figure(figsize=(12, 10))
sns.distplot(df_train['SalePrice'])

# %%
df_train['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
df_train['SalePrice'].kurt()
# Out:
# 6.536281860064529

# %%
df_train['HasBsmt'] = pd.Series(
    len(df_train['TotalBsmtSF']), index=df_train.index)

# %%
df_train['HasBsmt'] = 0

# %%
df_train['TotalBsmtSF']
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
# 5        796
# 6       1686
# 7       1107
# 8        952
# 9        991
# 10      1040
# 11      1175
# 12       912
# 13      1494
# 14      1253
# 15       832
# 16      1004
# 17         0
# 18      1114
# 19      1029
# 20      1158
# 21       637
# 22      1777
# 23      1040
# 24      1060
# 25      1566
# 26       900
# 27      1704
# 28      1484
# 29       520
#         ...
# 1430     732
# 1431     958
# 1432     656
# 1433     936
# 1434    1126
# 1435    1319
# 1436     864
# 1437    1932
# 1438     912
# 1439     539
# 1440     588
# 1441     848
# 1442    1017
# 1443     952
# 1444    1422
# 1445     814
# 1446    1188
# 1447    1220
# 1448     560
# 1449     630
# 1450     896
# 1451    1573
# 1452     547
# 1453    1140
# 1454    1221
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_train.loc[df_train['TotalBsmtSF'] > 0, 'HasBsmt'] = 1

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities   ...    PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0            Lvl    AllPub   ...       NaN    NaN         NaN       0      2
# 1            Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 2            Lvl    AllPub   ...       NaN    NaN         NaN       0      9
# 3            Lvl    AllPub   ...       NaN    NaN         NaN       0      2
# 4            Lvl    AllPub   ...       NaN    NaN         NaN       0     12
# 5            Lvl    AllPub   ...       NaN  MnPrv        Shed     700     10
# 6            Lvl    AllPub   ...       NaN    NaN         NaN       0      8
# 7            Lvl    AllPub   ...       NaN    NaN        Shed     350     11
# 8            Lvl    AllPub   ...       NaN    NaN         NaN       0      4
# 9            Lvl    AllPub   ...       NaN    NaN         NaN       0      1
# 10           Lvl    AllPub   ...       NaN    NaN         NaN       0      2
# 11           Lvl    AllPub   ...       NaN    NaN         NaN       0      7
# 12           Lvl    AllPub   ...       NaN    NaN         NaN       0      9
# 13           Lvl    AllPub   ...       NaN    NaN         NaN       0      8
# 14           Lvl    AllPub   ...       NaN   GdWo         NaN       0      5
# 15           Lvl    AllPub   ...       NaN  GdPrv         NaN       0      7
# 16           Lvl    AllPub   ...       NaN    NaN        Shed     700      3
# 17           Lvl    AllPub   ...       NaN    NaN        Shed     500     10
# 18           Lvl    AllPub   ...       NaN    NaN         NaN       0      6
# 19           Lvl    AllPub   ...       NaN  MnPrv         NaN       0      5
# 20           Lvl    AllPub   ...       NaN    NaN         NaN       0     11
# 21           Bnk    AllPub   ...       NaN  GdPrv         NaN       0      6
# 22           Lvl    AllPub   ...       NaN    NaN         NaN       0      9
# 23           Lvl    AllPub   ...       NaN    NaN         NaN       0      6
# 24           Lvl    AllPub   ...       NaN  MnPrv         NaN       0      5
# 25           Lvl    AllPub   ...       NaN    NaN         NaN       0      7
# 26           Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 27           Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 28           Lvl    AllPub   ...       NaN    NaN         NaN       0     12
# 29           Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# ...          ...       ...   ...       ...    ...         ...     ...    ...
# 1430         Lvl    AllPub   ...       NaN    NaN         NaN       0      7
# 1431         Lvl    AllPub   ...       NaN    NaN         NaN       0     10
# 1432         Lvl    AllPub   ...       NaN    NaN         NaN       0      8
# 1433         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1434         Low    AllPub   ...       NaN    NaN         NaN       0      5
# 1435         Lvl    AllPub   ...       NaN  GdPrv         NaN       0      7
# 1436         Lvl    AllPub   ...       NaN   GdWo         NaN       0      5
# 1437         Lvl    AllPub   ...       NaN    NaN         NaN       0     11
# 1438         Lvl    AllPub   ...       NaN  MnPrv         NaN       0      4
# 1439         Lvl    AllPub   ...       NaN    NaN         NaN       0     11
# 1440         Bnk    AllPub   ...       NaN    NaN         NaN       0      9
# 1441         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1442         Lvl    AllPub   ...       NaN    NaN         NaN       0      4
# 1443         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1444         Lvl    AllPub   ...       NaN    NaN         NaN       0     11
# 1445         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1446         Lvl    AllPub   ...       NaN    NaN         NaN       0      4
# 1447         Lvl    AllPub   ...       NaN    NaN         NaN       0     12
# 1448         Lvl    AllPub   ...       NaN   GdWo         NaN       0      5
# 1449         Lvl    AllPub   ...       NaN    NaN         NaN       0      8
# 1450         Lvl    AllPub   ...       NaN    NaN         NaN       0      9
# 1451         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1452         Lvl    AllPub   ...       NaN    NaN         NaN       0      5
# 1453         Lvl    AllPub   ...       NaN    NaN         NaN       0      7
# 1454         Lvl    AllPub   ...       NaN    NaN         NaN       0     10
# 1455         Lvl    AllPub   ...       NaN    NaN         NaN       0      8
# 1456         Lvl    AllPub   ...       NaN  MnPrv         NaN       0      2
# 1457         Lvl    AllPub   ...       NaN  GdPrv        Shed    2500      5
# 1458         Lvl    AllPub   ...       NaN    NaN         NaN       0      4
# 1459         Lvl    AllPub   ...       NaN    NaN         NaN       0      6
#
#      YrSold SaleType  SaleCondition  SalePrice  HasBsmt
# 0      2008       WD         Normal     208500        1
# 1      2007       WD         Normal     181500        1
# 2      2008       WD         Normal     223500        1
# 3      2006       WD        Abnorml     140000        1
# 4      2008       WD         Normal     250000        1
# 5      2009       WD         Normal     143000        1
# 6      2007       WD         Normal     307000        1
# 7      2009       WD         Normal     200000        1
# 8      2008       WD        Abnorml     129900        1
# 9      2008       WD         Normal     118000        1
# 10     2008       WD         Normal     129500        1
# 11     2006      New        Partial     345000        1
# 12     2008       WD         Normal     144000        1
# 13     2007      New        Partial     279500        1
# 14     2008       WD         Normal     157000        1
# 15     2007       WD         Normal     132000        1
# 16     2010       WD         Normal     149000        1
# 17     2006       WD         Normal      90000        0
# 18     2008       WD         Normal     159000        1
# 19     2009      COD        Abnorml     139000        1
# 20     2006      New        Partial     325300        1
# 21     2007       WD         Normal     139400        1
# 22     2008       WD         Normal     230000        1
# 23     2007       WD         Normal     129900        1
# 24     2010       WD         Normal     154000        1
# 25     2009       WD         Normal     256300        1
# 26     2010       WD         Normal     134800        1
# 27     2010       WD         Normal     306000        1
# 28     2006       WD         Normal     207500        1
# 29     2008       WD         Normal      68500        1
# ...     ...      ...            ...        ...      ...
# 1430   2006       WD         Normal     192140        1
# 1431   2009       WD         Normal     143750        1
# 1432   2007       WD         Normal      64500        1
# 1433   2008       WD         Normal     186500        1
# 1434   2006       WD         Normal     160000        1
# 1435   2008      COD        Abnorml     174000        1
# 1436   2007       WD         Normal     120500        1
# 1437   2008      New        Partial     394617        1
# 1438   2010       WD         Normal     149700        1
# 1439   2007       WD         Normal     197000        1
# 1440   2008       WD         Normal     191000        1
# 1441   2008       WD         Normal     149300        1
# 1442   2009       WD         Normal     310000        1
# 1443   2009       WD         Normal     121000        1
# 1444   2007       WD         Normal     179600        1
# 1445   2007       WD         Normal     129000        1
# 1446   2010       WD         Normal     157900        1
# 1447   2007       WD         Normal     240000        1
# 1448   2007       WD         Normal     112000        1
# 1449   2006       WD        Abnorml      92000        1
# 1450   2009       WD         Normal     136000        1
# 1451   2009      New        Partial     287090        1
# 1452   2006       WD         Normal     145000        1
# 1453   2006       WD        Abnorml      84500        1
# 1454   2009       WD         Normal     185000        1
# 1455   2007       WD         Normal     175000        1
# 1456   2010       WD         Normal     210000        1
# 1457   2010       WD         Normal     266500        1
# 1458   2010       WD         Normal     142125        1
# 1459   2008       WD         Normal     147500        1
#
# [1460 rows x 82 columns]
