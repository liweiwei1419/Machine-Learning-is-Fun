# %%
# %%time
import pandas as pd

train = pd.read_csv('../input/train.csv')
# Out:
# CPU times: user 5.71 ms, sys: 2.27 ms, total: 7.99 ms
# Wall time: 6.13 ms

# %% [markdown]
# ## 特征工程

# %%
# 缺失值填充，离散型变量转换成数值


def feature_preprocessing(data):
    data['Sex'] = data['Sex'].map(lambda x: 1 if x == 'male' else 0)
    data['Embarked'] = data['Embarked'].fillna(
        data['Embarked'].mode().values[0])
    data['Age'] = data['Age'].fillna(data['Age'].median())

    Pclass_dummies = pd.get_dummies(data['Pclass'], prefix='Pclass_')
    Embarked_dummies = pd.get_dummies(data['Embarked'], prefix='Embarked')

    # 丢弃姓名、客舱 Cabin 、船票信息 Ticket
    data.drop(
        columns=[
            'Name', 'Cabin', 'Ticket', 'Pclass', 'Embarked', 'PassengerId'
        ],
        inplace=True)

    data = pd.concat([data, Pclass_dummies, Embarked_dummies], axis=1)
    return data


train = feature_preprocessing(train)

# %%
train.head()
# Out:
#    Survived  Sex   Age  SibSp  Parch     Fare  Pclass__1  Pclass__2  \
# 0         0    1  22.0      1      0   7.2500          0          0
# 1         1    0  38.0      1      0  71.2833          1          0
# 2         1    0  26.0      0      0   7.9250          0          0
# 3         1    0  35.0      1      0  53.1000          1          0
# 4         0    1  35.0      0      0   8.0500          0          0
#
#    Pclass__3  Embarked_C  Embarked_Q  Embarked_S
# 0          1           0           0           1
# 1          0           1           0           0
# 2          1           0           0           1
# 3          0           0           0           1
# 4          1           0           0           1

# %%
def split_X_y(data):

    X = data.drop(['Survived'], axis=1)
    y = data['Survived']
    return X, y

X, y = split_X_y(train)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=666)

# %% [markdown]
# ## 使用不同的模型

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

dt = DecisionTreeClassifier(random_state=666)
lr = LogisticRegression(solver='newton-cg')
rfc = RandomForestClassifier(n_estimators=100, random_state=666)
svc = SVC(kernel='rbf', gamma='scale')
ada = AdaBoostClassifier()
gbc = GradientBoostingClassifier()
xgb = XGBClassifier()

models = [('DecisionTreeClassifier', dt), ('LogisticRegression', lr),
          ('RandomForestClassifier', rfc), ('svc', svc),
          ('AdaBoostClassifier', ada), ('GradientBoostingClassifier',
                                        gbc), ('XBClassifier', xgb)]

# %%
from sklearn.model_selection import cross_val_score


def predict_by_different_models(models):
    res = dict()
    for model in models:
        model_name = model[0]
        clf = model[1]
        clf.fit(X_train, y_train)
        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)
        res[model_name] = {
            'train_score': train_score,
            'test_score': test_score
        }
    return res

# %%
# %%time

res = predict_by_different_models(models)
# Out:
# CPU times: user 352 ms, sys: 3.47 ms, total: 356 ms
# Wall time: 354 ms

# %%
res = pd.DataFrame(res).T
res.reindex(columns=['train_score', 'test_score'])
# Out:
#                             train_score  test_score
# DecisionTreeClassifier         0.980337    0.793296
# LogisticRegression             0.814607    0.782123
# RandomForestClassifier         0.980337    0.837989
# svc                            0.686798    0.670391
# AdaBoostClassifier             0.838483    0.810056
# GradientBoostingClassifier     0.891854    0.810056
# XBClassifier                   0.876404    0.793296

# %% [markdown]
# 可以看出，随机森林的效果最好。
# 把全部训练数据用上。

# %% [markdown]
# ## 使用网格搜索选择超参数

# %% [markdown]
# ### 决策树

# %%
# %%time
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

entropy_thresholds = np.linspace(0, 1, 50)
gini_thresholds = np.linspace(0, 0.5, 50)

parameters = [{
    'criterion': ['entropy'],
    'min_impurity_decrease': entropy_thresholds
}, {
    'criterion': ['gini'],
    'min_impurity_decrease': gini_thresholds
}, {
    'max_depth': range(2, 10)
}, {
    'min_impurity_decrease': range(2, 30, 2)
}]

dt = RandomForestClassifier(n_estimators=100)
clf = GridSearchCV(dt, parameters, cv=5, verbose=2)
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 122 candidates, totalling 610 fits
# [CV] criterion=entropy, min_impurity_decrease=0.0 ....................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... criterion=entropy, min_impurity_decrease=0.0, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.0 ....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ..... criterion=entropy, min_impurity_decrease=0.0, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.0 ....................
# [CV] ..... criterion=entropy, min_impurity_decrease=0.0, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.0 ....................
# [CV] ..... criterion=entropy, min_impurity_decrease=0.0, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.0 ....................
# [CV] ..... criterion=entropy, min_impurity_decrease=0.0, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.02040816326530612 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.02040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.02040816326530612 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.02040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.02040816326530612 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.02040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.02040816326530612 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.02040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.02040816326530612 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.02040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.04081632653061224 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.04081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.04081632653061224 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.04081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.04081632653061224 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.04081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.04081632653061224 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.04081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.04081632653061224 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.04081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.061224489795918366 ...
# [CV]  criterion=entropy, min_impurity_decrease=0.061224489795918366, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.061224489795918366 ...
# [CV]  criterion=entropy, min_impurity_decrease=0.061224489795918366, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.061224489795918366 ...
# [CV]  criterion=entropy, min_impurity_decrease=0.061224489795918366, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.061224489795918366 ...
# [CV]  criterion=entropy, min_impurity_decrease=0.061224489795918366, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.061224489795918366 ...
# [CV]  criterion=entropy, min_impurity_decrease=0.061224489795918366, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.08163265306122448 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.08163265306122448, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.08163265306122448 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.08163265306122448, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.08163265306122448 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.08163265306122448, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.08163265306122448 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.08163265306122448, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.08163265306122448 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.08163265306122448, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.1020408163265306 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.1020408163265306, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.1020408163265306 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.1020408163265306, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.1020408163265306 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.1020408163265306, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.1020408163265306 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.1020408163265306, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.1020408163265306 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.1020408163265306, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.12244897959183673 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.12244897959183673, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.12244897959183673 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.12244897959183673, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.12244897959183673 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.12244897959183673, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.12244897959183673 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.12244897959183673, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.12244897959183673 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.12244897959183673, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.14285714285714285 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.14285714285714285, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.14285714285714285 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.14285714285714285, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.14285714285714285 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.14285714285714285, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.14285714285714285 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.14285714285714285, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.14285714285714285 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.14285714285714285, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.16326530612244897 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.16326530612244897, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.16326530612244897 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.16326530612244897, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.16326530612244897 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.16326530612244897, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.16326530612244897 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.16326530612244897, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.16326530612244897 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.16326530612244897, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.18367346938775508 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.18367346938775508, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.18367346938775508 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.18367346938775508, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.18367346938775508 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.18367346938775508, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.18367346938775508 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.18367346938775508, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.18367346938775508 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.18367346938775508, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2040816326530612 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2040816326530612 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2040816326530612 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2040816326530612 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2040816326530612 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2040816326530612, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.22448979591836732 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.22448979591836732, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.22448979591836732 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.22448979591836732, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.22448979591836732 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.22448979591836732, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.22448979591836732 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.22448979591836732, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.22448979591836732 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.22448979591836732, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.24489795918367346 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.24489795918367346, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.24489795918367346 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.24489795918367346, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.24489795918367346 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.24489795918367346, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.24489795918367346 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.24489795918367346, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.24489795918367346 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.24489795918367346, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.26530612244897955 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.26530612244897955, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.26530612244897955 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.26530612244897955, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.26530612244897955 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.26530612244897955, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.26530612244897955 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.26530612244897955, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.26530612244897955 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.26530612244897955, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2857142857142857 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2857142857142857, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2857142857142857 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2857142857142857, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2857142857142857 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2857142857142857, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2857142857142857 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2857142857142857, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.2857142857142857 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.2857142857142857, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3061224489795918 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3061224489795918, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3061224489795918 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3061224489795918, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3061224489795918 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3061224489795918, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3061224489795918 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3061224489795918, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3061224489795918 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3061224489795918, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.32653061224489793 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.32653061224489793, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.32653061224489793 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.32653061224489793, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.32653061224489793 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.32653061224489793, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.32653061224489793 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.32653061224489793, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.32653061224489793 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.32653061224489793, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3469387755102041 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3469387755102041, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3469387755102041 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3469387755102041, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3469387755102041 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3469387755102041, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3469387755102041 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3469387755102041, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3469387755102041 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3469387755102041, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.36734693877551017 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.36734693877551017, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.36734693877551017 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.36734693877551017, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.36734693877551017 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.36734693877551017, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.36734693877551017 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.36734693877551017, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.36734693877551017 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.36734693877551017, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3877551020408163 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3877551020408163, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3877551020408163 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3877551020408163, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3877551020408163 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3877551020408163, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3877551020408163 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3877551020408163, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.3877551020408163 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.3877551020408163, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4081632653061224 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4081632653061224 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4081632653061224 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4081632653061224 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4081632653061224 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4081632653061224, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.42857142857142855 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.42857142857142855, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.42857142857142855 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.42857142857142855, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.42857142857142855 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.42857142857142855, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.42857142857142855 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.42857142857142855, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.42857142857142855 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.42857142857142855, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.44897959183673464 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.44897959183673464, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.44897959183673464 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.44897959183673464, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.44897959183673464 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.44897959183673464, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.44897959183673464 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.44897959183673464, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.44897959183673464 ....
# [CV]  criterion=entropy, min_impurity_decrease=0.44897959183673464, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4693877551020408 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4693877551020408, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4693877551020408 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4693877551020408, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4693877551020408 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4693877551020408, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4693877551020408 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4693877551020408, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4693877551020408 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4693877551020408, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4897959183673469 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4897959183673469, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4897959183673469 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4897959183673469, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4897959183673469 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4897959183673469, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4897959183673469 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4897959183673469, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.4897959183673469 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.4897959183673469, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5102040816326531 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.5102040816326531, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5102040816326531 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.5102040816326531, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5102040816326531 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.5102040816326531, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5102040816326531 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.5102040816326531, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5102040816326531 .....
# [CV]  criterion=entropy, min_impurity_decrease=0.5102040816326531, total=   0.1s
# [CV] criterion=entropy, min_impurity_decrease=0.5306122448979591 .....

# %%
clf.best_score_

# %%
clf.best_params_

# %%
clf.best_estimator_.score(X_test, y_test)

# %% [markdown]
# ### 随机森林

# %%
# %%time
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=500)


parameters = {'max_depth': list(range(2, 10)),
              'min_samples_split': list(range(2, 10)),
              'min_samples_leaf': list(range(2, 10)),
              'max_features': list(range(1, 9))}

clf = GridSearchCV(rfr, parameters, cv=5,verbose=2)
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4096 candidates, totalling 20480 fits
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4, total=   0.5s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=2, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=3, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6, total=   0.4s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=4, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=7, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9
# [CV]  max_depth=2, max_features=1, min_samples_leaf=8, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3
# [CV]  max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=1, min_samples_leaf=9, min_samples_split=3
# ...
# [CV]  max_depth=2, max_features=4, min_samples_leaf=5, min_samples_split=9, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=4, min_samples_leaf=5, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=5, min_samples_split=9
# [CV]  max_depth=2, max_features=4, min_samples_leaf=5, min_samples_split=9, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=2, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=3, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=4, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=5, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=6, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=7, total=   0.4s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=8, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=9
# [CV]  max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=9, total=   0.3s
# [CV] max_depth=2, max_features=4, min_samples_leaf=6, min_samples_split=9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-200-ff1600c41b3e> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', "from sklearn.model_selection import GridSearchCV\nfrom sklearn.ensemble import RandomForestRegressor\n\nrfr = RandomForestRegressor(n_estimators=500)\n\n\nparameters = {'max_depth': list(range(2, 10)),\n              'min_samples_split': list(range(2, 10)),\n              'min_samples_leaf': list(range(2, 10)),\n              'max_features': list(range(1, 9))}\n\nclf = GridSearchCV(rfr, parameters, cv=5,verbose=2)\nclf.fit(X_train, y_train)")
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1183         else:
#    1184             st = clock2()
# -> 1185             exec(code, glob, local_ns)
#    1186             end = clock2()
#    1187             out = None
#
# <timed exec> in <module>()
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     317             for i in range(n_more_estimators):
#     318                 tree = self._make_estimator(append=False,
# --> 319                                             random_state=random_state)
#     320                 trees.append(tree)
#     321
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/ensemble/base.py in _make_estimator(self, append, random_state)
#     126         estimator = clone(self.base_estimator_)
#     127         estimator.set_params(**dict((p, getattr(self, p))
# --> 128                                     for p in self.estimator_params))
#     129
#     130         if random_state is not None:
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/base.py in set_params(self, **params)
#     202             # Simple optimization to gain speed (inspect is slow)
#     203             return self
# --> 204         valid_params = self.get_params(deep=True)
#     205
#     206         nested_params = defaultdict(dict)  # grouped by prefix
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/base.py in get_params(self, deep)
#     179         """
#     180         out = dict()
# --> 181         for key in self._get_param_names():
#     182             value = getattr(self, key, None)
#     183             if deep and hasattr(value, 'get_params'):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/sklearn/base.py in _get_param_names(cls)
#     149         # introspect the constructor arguments to find the model parameters
#     150         # to represent
# --> 151         init_signature = signature(init)
#     152         # Consider the constructor parameters excluding 'self'
#     153         parameters = [p for p in init_signature.parameters.values()
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/inspect.py in signature(obj, follow_wrapped)
#    2999 def signature(obj, *, follow_wrapped=True):
#    3000     """Get a signature object for the passed callable."""
# -> 3001     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3002
#    3003
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2749         """Constructs Signature for the given callable object."""
#    2750         return _signature_from_callable(obj, sigcls=cls,
# -> 2751                                         follow_wrapper_chains=follow_wrapped)
#    2752
#    2753     @property
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2224         # If it's a pure Python function, or an object that is duck type
#    2225         # of a Python function (Cython functions, for instance), then:
# -> 2226         return _signature_from_function(sigcls, obj)
#    2227
#    2228     if _signature_is_builtin(obj):
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/inspect.py in _signature_from_function(cls, func)
#    2100         annotation = annotations.get(name, _empty)
#    2101         parameters.append(Parameter(name, annotation=annotation,
# -> 2102                                     kind=_POSITIONAL_OR_KEYWORD))
#    2103
#    2104     # ... w/ defaults.
#
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/inspect.py in __init__(self, name, kind, default, annotation)
#    2414             raise ValueError('name is a required attribute for Parameter')
#    2415
# -> 2416         if not isinstance(name, str):
#    2417             raise TypeError("name must be a str, not a {!r}".format(name))
#    2418
#
# KeyboardInterrupt:

# %%
clf.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 20}

# %%
clf.best_score_
# Out:
# 0.4424730367805543

# %%
entropy_thresholds
# Out:
# array([0.        , 0.02040816, 0.04081633, 0.06122449, 0.08163265,
#        0.10204082, 0.12244898, 0.14285714, 0.16326531, 0.18367347,
#        0.20408163, 0.2244898 , 0.24489796, 0.26530612, 0.28571429,
#        0.30612245, 0.32653061, 0.34693878, 0.36734694, 0.3877551 ,
#        0.40816327, 0.42857143, 0.44897959, 0.46938776, 0.48979592,
#        0.51020408, 0.53061224, 0.55102041, 0.57142857, 0.59183673,
#        0.6122449 , 0.63265306, 0.65306122, 0.67346939, 0.69387755,
#        0.71428571, 0.73469388, 0.75510204, 0.7755102 , 0.79591837,
#        0.81632653, 0.83673469, 0.85714286, 0.87755102, 0.89795918,
#        0.91836735, 0.93877551, 0.95918367, 0.97959184, 1.        ])

# %%
clf.best_estimator_.score(X_test, y_test)
# Out:
# 0.7877094972067039
