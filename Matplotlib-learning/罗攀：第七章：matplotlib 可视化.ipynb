# %% [markdown]
# # 罗攀：第七章：matplotlib 可视化
#
#
# 1、plot 默认绘制的是折线图；
#
# 2、bar 绘制柱状图，Series 的数据可以用柱状图展示；
#
# 3、刻度用 xticks() 和 yticks() ；
#
# 4、散点图用 scatter；
#
# 5、直方图用 plt.hist，指定分组数量；
#
# 6、创建多子图：
#
# 方法1：先创建一个 figure ，然后在这个 figure 对象上， add_subplot
#
# 方法2：直接使用 subplots 创建 figure 和 axes 对象；
#
# 设置子图间距，使用 plt.subplots_adjust 方法
#
# 7、文本注解，使用 text 。

# %% [markdown]
# ## plot 默认绘制折线图

# %%
import pandas as pd

data = {
    'name': ['张三', '李四', '王五', '小明'],
    'sex': ['female', 'female', 'male', 'male'],
    'math': [78, 79, 83, 92],
    'city': ['北京', '上海', '广州', '北京']
}
df = pd.DataFrame(data)
df
# Out:
#   name     sex  math city
# 0   张三  female    78   北京
# 1   李四  female    79   上海
# 2   王五    male    83   广州
# 3   小明    male    92   北京

# %%
plt.plot(df.index, df['math'])
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['STHeiti'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
plt.plot(years, gdp, color='r')
plt.show()

# %%
plt.plot(years, gdp, color='#FFA500')
plt.show()

# %%
plt.plot(years, gdp, linestyle='--')
plt.show()

# %%
plt.plot(years, gdp, linestyle='--', linewidth=5)
plt.show()

# %%
plt.plot(years, gdp, marker='.')
plt.show()

# %%
plt.plot(years, gdp, marker='D')
plt.show()

# %%
# c 表示一种颜色
plt.plot(years, gdp, 'co--')
plt.show()

# %% [markdown]
# # 柱状图

# %%
data = [23, 85, 72, 43, 52]
plt.bar([1, 2, 3, 4, 5], data)
plt.show()

# %%
plt.bar(range(len(data)), data, color='royalblue', alpha=0.7)
plt.show()

# %% [markdown]
# ### 设置网格的样式

# %%
plt.bar(range(len(data)), data, color='green', alpha=0.7)
# 设置网格的样式
plt.grid(color='#95a5a6', linestyle='--', linewidth=1, axis='y', alpha=0.6)
plt.show()

# %% [markdown]
# ### 使用 bottom 属性设置垂直叠加效果

# %%
# 叠加效果
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
plt.bar(range(len(data)), data1)
plt.bar(range(len(data)), data2, bottom=data1)
plt.show()

# %% [markdown]
# ### 使用 width 属性设置水平排列效果

# %%
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
# 偏移量
width = 0.3
plt.bar(np.arange(len(data1)), data1, width=width)
plt.bar(np.arange(len(data2)) + width, data2, width=width)
plt.show()

# %% [markdown]
# ### 水平柱状图

# %%
data1 = [23, 85, 72, 43, 52]
plt.barh(range(len(data1)), data1)
plt.show()

# %%
data = [23, 85, 72, 43, 52]
labels = ['A', 'B', 'C', 'D', 'E']
plt.xticks(range(len(data)), labels)  # 设置刻度和标签
plt.bar(range(len(data)), data)
plt.show()

# %% [markdown]
# ### 使用 xtick 属性设置刻度和标签

# %%
data = [23, 85, 72, 43, 52]
labels = ['A', 'B', 'C', 'D', 'E']
plt.xticks(range(len(data)), labels)  
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)), data)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['STHeiti'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
data1 = [23, 85, 72, 43, 52]
data2 = [42, 35, 21, 16, 9]
width = 0.3
plt.bar(np.arange(len(data1)), data1, width=width, label='one')
plt.bar(np.arange(len(data2)) + width, data2, width=width, label='two')
plt.legend()
plt.show()

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sex_mean = tips.groupby('sex')['tip'].mean()
sex_mean
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
labels = list(sex_mean.index)  # 刻度标签
plt.xlabel('sex')  # 设置 X 轴标签
plt.ylabel('tip')  # 设置 Y 轴标签
plt.bar(range(len(labels)), sex_mean, width=0.5)
plt.xticks(range(len(labels)), labels, fontsize=12)  # 设置刻度和刻度标签
plt.show()

# %% [markdown]
# ## 绘制散点图

# %%
X = np.random.randn(100)
Y = np.random.randn(100)
plt.scatter(X, Y)
plt.show()

# %%
plt.scatter(X, Y, color='red', marker='D')
plt.show()

# %% [markdown]
# ## 绘制频率分布直方图

# %%
x = np.random.normal(size=100)
plt.hist(x, bins=30)
plt.show()

# %% [markdown]
# ## 绘制子图

# %% [markdown]
# ### 使用 add_subplot 绘制子图

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
ax1.scatter(years, gdp)
ax2.plot(years, gdp)
ax3.bar(years, gdp)
plt.show()

# %% [markdown]
# ### 使用 subplots 绘制子图

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 6))
axes[1, 0].plot(years, gdp)
plt.show()

# %%
fig, axes = plt.subplots(2, 2)
plt.show()

# %% [markdown]
# ### 设置子图的边距 subplots_adjust

# %%
fig, axes = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()

# %% [markdown]
# ### 添加文本注解

# %%
data = [23, 85, 72, 43, 52]
labels = ['A', 'B', 'C', 'D', 'E']
plt.xticks(range(len(data)), labels)  # 设置刻度和标签
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)), data)

for x, y in zip(range(len(data)), data):
    plt.text(x, y, y, ha='center', va='bottom')  # 文本注解
plt.show()

# %%
plt.style.use('ggplot')
data = [23, 85, 72, 43, 52]
labels = ['A', 'B', 'C', 'D', 'E']
plt.xticks(range(len(data)), labels)  # 设置刻度和标签
plt.xlabel('Class')
plt.ylabel('Amounts')
plt.title('Example1')
plt.bar(range(len(data)), data)
for x, y in zip(range(len(data)), data):
    plt.text(x, y, y, ha='center', va='bottom')  # 文本注解
plt.show()

# %% [markdown]
# ## 显示中文

# %%
# 在我的 notebook 里，要设置下面两行才能显示中文
plt.rcParams['font.family'] = ['sans-serif']
# 如果是在 PyCharm 里，只要下面一行，上面的一行可以删除
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

plt.title('案例')
plt.show()

# %%
plt.rcParams['font.sans-serif'] = ['simhei']  # 指定默认字体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题


# 在我的 notebook 里，要设置下面两行才能显示中文
plt.rcParams['font.family'] = ['sans-serif']
# 如果是在 PyCharm 里，只要下面一行，上面的一行可以删除
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

plt.title('案例')
# Out:
# Text(0.5, 1.0, '案例')

# %% [markdown]
# ### 直接指定字体位置

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='/Users/liwei/Library/Fonts/simkai.ttf', size=20)

plt.title('案例', fontproperties=font)
# Out:
# Text(0.5, 1.0, '案例')
