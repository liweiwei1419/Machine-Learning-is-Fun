# %% [markdown]
# # seaborn可视化
#
# 去坐标轴：sns.despine()  。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 绘制散点图

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
plt.scatter(years, gdp)
plt.show()

# %% [markdown]
# ## 设置 seaborn 的样式
#
# sns.set_style("darkgrid")
#
# 五种主题样式：
#
# 1、darkgrid；
#
# 2、dark；
#
# 3、whitegrid；
#
# 4、white；
#
# 5、ticks。

# %%
sns.set_style("darkgrid")
plt.scatter(years, gdp)
plt.show()

# %%
# dark 这个主题就不会显示网格了
sns.set_style("dark")
plt.scatter(years, gdp)
plt.show()

# %% [markdown]
# ### 更普遍地是使用 set 方法，可以设置主题、调色板、颜色代码 color_codes

# %%
sns.set(style="white", palette="muted", color_codes=True)  # set( )设置主题，调色板，颜色主题更常用
plt.plot(np.arange(10))
plt.show()

# %% [markdown]
# ## 坐标轴移除
#
# 使用 `sns.despine()`，去掉了顶部和右侧。

# %%
sns.set(style="white", palette="muted", color_codes=True)  # set( )设置主题，调色板更常用
plt.plot(np.arange(10))
sns.despine() # 把边框去掉了一些
plt.show()

# %% [markdown]
# 设置偏移（好像没有什么用）。

# %%
sns.set(style="white", palette="muted", color_codes=True)  # set( )设置主题，调色板更常用
plt.plot(np.arange(10))
sns.despine(offset=10, trim=True)  # 设置边框偏移
plt.show()

# %%
sns.set(style="whitegrid", palette="muted", color_codes=True)

# sns.set()
plt.plot(np.arange(10))
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ## 单变量分布图
#
# 可以选择画直方图、概率密度曲线图还有毛坦图。

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 数值型、连续型变量可以画单变量分布图。

# %%
tips['total_bill'].dtype
# Out:
# dtype('float64')

# %%
# tips['total_bill'] 表示只有一个变量的数据

sns.set(color_codes=True)
sns.distplot(tips['total_bill'])
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# rug 表示显示毛毯图
sns.distplot(tips['total_bill'], kde=False, rug=True)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.distplot(tips['total_bill'], bins=30, kde=False, rug=True)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.distplot(tips['total_bill'], hist=False, rug=True)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 学习 subplots 的用法（重要）

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
# 分布图，kde=False 不显示密度
sns.distplot(tips['total_bill'], ax=axes[0], kde=False)
# 毛毯图
sns.rugplot(tips['total_bill'], ax=axes[0])

# 直接画密度图
sns.kdeplot(tips['total_bill'], ax=axes[1], shade=True)   # shade  阴影
# 毛毯图
sns.rugplot(tips['total_bill'], ax=axes[1])
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ## 多变量分布图

# %% [markdown]
# ### 针对两个连续型、数值型变量，可以观察他们的相关关系
#
# 使用 joinplot 还可以看他们的分布情况。

# %%
sns.jointplot(x="tip", y="total_bill", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# ...

# %% [markdown]
# 使用 `kind='kde'`，默认的直方图就变成了密度图。

# %%
# 图上还显示了相关系数
sns.jointplot(x="tip", y="total_bill", data=tips, kind='kde')
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 绘制成对的二元连续型变量分布图

# %%
# 以轴矩阵的方式显示
# 小费数据多变量分布图
sns.pairplot(tips, size=2.5)
plt.show()

# %% [markdown]
# ## 对于类别变量的数据展示
#
# ### 分类散点图
#
# stripplot、swarmplot 可以看清每个数据点。

# %% [markdown]
# ### 用一个类别变量去划分连续型变量

# %%
sns.set(style="white", color_codes=True)  # 设置样式

sns.stripplot(x="day", y="total_bill", data=tips)
sns.despine()  # 去坐标轴
plt.show()

# %%
# jitter=True 表示会有一些抖动，这样数值相近的点就不会挤在一起了
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, size=10)
sns.despine()
plt.show()

# %% [markdown]
# ## swarmplot 比上面的 stripplot 加上抖动看得还更清楚一点

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, size=10)
sns.despine()
plt.show()

# %% [markdown]
# ## hue="sex" 表示，在第 1 分类变量 day 的基础上，设置第 2 分类变量，即嵌套分类变量

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips, size=10)
sns.despine()
plt.show()

# %% [markdown]
# ## 箱线图可以观察每个分类下连续型变量的四分位数、中位数和极值

# %%
# 箱线图，hue="time" 第 2 分类变量
sns.boxplot(x="day", y="total_bill", hue="time", data=tips)
sns.despine()
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %% [markdown]
# ## 小提琴图是能让你看到分布的，把直方图给显示了出来

# %% [markdown]
# ### hue="time" 第 2 分类变量，x 和 y 那个是分类变量，就决定了小提琴图的横向与纵向

# %%
sns.set(style="whitegrid", color_codes=True)

sns.violinplot(x="total_bill", y="day", hue="time", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # 这里 subplots 的用法上面也用到过

# %%
sns.set(style="whitegrid", color_codes=True)
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True, ax=axes[0])
# 对数据进行切分，inner="stick" 
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True, inner="stick", palette="Set3", ax=axes[1])
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:885: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:905: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# ...

# %% [markdown]
# ## 把之前的图进行组合，产生更强大的效果（相当于几种图叠加在一起显示了出来）

# %%
sns.set(style="whitegrid", color_codes=True)
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
# 设置样式与子图

sns.violinplot(x="day", y="total_bill", data=tips,inner=None, ax=axes[0])
# inner内部不填充
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5, ax=axes[0])

sns.boxplot(x="day", y="total_bill", data=tips, ax=axes[1])
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, color="w", alpha=.5, ax=axes[1])
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# # 柱状图

# %% [markdown]
# ## 这里的柱状图是使用了汇总的，默认的汇总方式是“mean”

# %%
# 这里 x 是离散型变量
# hue 是第二分类变量

sns.barplot(x="sex", y="tip", hue="day", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 更改汇总方式
sns.barplot(x="sex", y="tip", hue="day", data=tips, estimator=sum)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 如果绘制柱状图，你的汇总方式是 count 计数，你就直接使用 countplot 好了

# %%
tips.groupby("size").count()
# Out:
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4

# %%
sns.countplot(x="size", data=tips, palette="Greens_d")
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ## 绘制回归图 regplot

# %%
sns.set(style="darkgrid", color_codes=True)
sns.regplot(x="total_bill", y="tip", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## lmplot

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 关闭置信区间
sns.lmplot(x="total_bill", y="tip", data=tips, ci=None)
plt.show()

# %% [markdown]
# ## 还可以再传入一个分类变量 hue

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## lmplot 功能就很强大了，col="time" 表示列方向上设置一个类别变量

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## col="time", row="sex" 表示在行列方向上都设置类别变量，所以就是你看到的 4 格表的样子

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           col="time", row="sex", data=tips)
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/scipy/stats/stats.py:1626: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 绘制网格

# %%
tips['tip'].head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
# 这里的 col 指定分类变量，取值是离散值
g = sns.FacetGrid(tips, col="time")
g.map(plt.hist, "tip") # "tip" 是连续型变量，设置绘制直方图
plt.show()

# %% [markdown]
# ## hue 指定图的内部分类

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(plt.scatter, "total_bill", "tip", alpha=.7)
g.add_legend()
plt.show()

# %% [markdown]
# # 设置了 col="sex", row='time' 就是显示行列联表了

# %%
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
tips['tip'].head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
g = sns.FacetGrid(tips, col="sex", row='time')
g.map(sns.boxplot, 'size', 'tip')
plt.show()
# Out:
# /Users/liwei/anaconda3/envs/ipykernel_py3/lib/python3.6/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
